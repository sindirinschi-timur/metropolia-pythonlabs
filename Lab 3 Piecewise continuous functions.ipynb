# %%
name = "Timur Sindirinschi" # Write your name between parenthesis
student_id = 2414326 # Change your student ID her
date_returned = "14/10/2024" # Write the date returned between the parenthesis

# %% [markdown]
# # Lab 3
# **Graphical representation of functions**<br>
# Software 1 course - Mathematics<br>
# Information and Communication Technology<br>
# Metropolia University of Applied Sciences
#
# ## Introduction
#
# In this third laboratory exercise we study how to write
# - unit step function (=piecewise continuous function)
# - rectangular pulse function by combining two unit step functions, and
# - arbitrary shaped pulse functions, like polynomial and triangular pulses
#
# The most important new skill to learn is how to use [boolean array indexing](https://numpy.org/doc/stable/user/basics.indexing.html#boolean-array-indexing). Here some links to the topic:
# - [numpy boolean indexing at python-course.eu](https://python-course.eu/numerical-programming/numpy-boolean-indexing.php)
# - [boolean numpy arrays at math.buffalo.edu](http://www.math.buffalo.edu/~badzioch/MTH337/PT/PT-boolean_numpy_arrays/PT-boolean_numpy_arrays.html)
#
# You can use [Moodle Quiz Lab 3](https://moodle.metropolia.fi/course/view.php?id=1960) to automatically check and verify your answers.

# %% [markdown]
# ## Setup
#
# Read necessary libraries. Notice that you need to import these libraries only once in the Notebook environment.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Problem 1
#
# The unit step function
#
# $ u(t) = \begin{cases}
# 1 & t \geq 0 \\
# 0 & t < 0
# \end{cases}$
#
# can be coded using numerical Python as given below.
#
# Sketch a graph of the unit step function $u(t)$ and annotate the graph.
# - Title: "Unit step function"
# - x-label: "Time (s)"
# - y-label: "Amplitude"
# - Add grid-lines
#
# Notice that the step-function and the values for *t* are already given, and you can use them to calculate the values of *f(t)*.

# %%
t = np.arange(-1, 5, 0.01)
u = 1.0*(t >= 0)

plt.figure(figsize=(8, 6))
plt.plot(t, u, label='Unit Step Function')
plt.title("Unit step function")
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ## Problem 2
#
# A delayed unit step function is defined as
#
# $ u(t-t_0) = \begin{cases}
# 1 & t \geq t_0 \\
# 0 & t < t_0
# \end{cases}$
#
# That can be coded just by replacing the value 0 to t0.
#
# Sketch a graph of delayed unit step function $u(t-3)$. Annotate the graph.
# - Title: "Delayed unit step function"
# - x-label: "Time (s)"
# - y-label: "Amplitude"
# - Add grid-lines
#
# Notice that the values for *t* are already given, and you can use them to calculate the values of *u(t - 3)*.

# %%
t = np.arange(-1, 5, 0.01)
u = np.where(t >= 3, 1.0, 0.0)

plt.figure(figsize=(8, 6))
plt.plot(t, u, label='Delayed Unit Step Function')
plt.title("Delayed unit step function")
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ## Problem 3
#
# [Rectangular pulse](https://en.wikipedia.org/wiki/Rectangular_function) can be defined as
#
# $ p(t, t_0, t_1) = \begin{cases}
# 1 & t_0 \leq t < t_1 \\
# 0 & \text{otherwise}
# \end{cases}$
#
# We can implement it using two delayed step functions and subtracting them, like $p(t, t_0, t_1) = u(t-t_0) - u(t-t_1)$.
#
# Sketch a graph of a rectangular pulse function $p = u(t-1) - u(t-3)$. Annotate the graph.
# - Title: "Rectangular pulse function"
# - x-label: "Time (s)"
# - y-label: "Amplitude"
# - Add grid-lines

# %%
t = np.arange(-1, 5, 0.01)
p = np.where((t >= 1) & (t < 3), 1.0, 0.0 )

plt.figure(figsize=(8, 6))
plt.plot(t, p, label = 'Rectangular pulse function')
plt.title("Rectangular pulse function")
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ## Problem 4
#
# By multiplying the rectangular pulse with another function, we can create pulse functions with arbitrary shape.
#
# Sketch a graph of a polynomial pulse $f = (-t^2 + 4t - 3) \cdot \left( u(t-1) - u(t-3) \right)$.
#
# Annotate the graph.
# - Title: "Polynomial pulse function"
# - x-label: "Time (s)"
# - y-label: "Amplitude"
# - Add grid-lines

# %%
t = np.arange(-1, 5, 0.01)
pulse = np.where((t >= 1) & (t < 3), 1, 0)
polynomial = -t**2 + 4*t - 3
f = polynomial * pulse
plt.figure(figsize=(8, 6))
plt.plot(t, f, label='Polynomial pulse Function')
plt.title("Polynomial pulse function")
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ## Problem 5
#
# Calculate the values for a [triangular function](https://en.wikipedia.org/wiki/Triangular_function)
#
# $$f = \begin{cases}
# t/2 & 0 \leq t < 2 \\
# -t/2 + 2 & 2 \leq t < 4 \\
# 0 & \text{otherwise}
# \end{cases}$$
#
# Sketch a graph of the function and annotate the graph.
# - Title: "Triangular pulse function"
# - x-label: "Time (s)"
# - y-label: "Amplitude"
# - Add grid-lines
#
# Tip: First, calculate the parts $f_1(t) = t/2$ (when $0 \leq t < 2$) and $f_2(t) = -t/2 + 2$ (when $2 \leq t < 4$), and then sum them together.

# %%
t = np.arange(-1, 5, 0.01)
f1 = np.where((t >= 0) & (t < 2), t / 2, 0)
f2 = np.where((t >= 2) & (t < 4), -t / 2 + 2, 0)
f = f1 + f2
plt.figure(figsize=(8, 6))
plt.plot(t, f, label='Triangular pulse function')
plt.title("Triangular pulse function")
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.grid(True)
plt.legend()
plt.show()
